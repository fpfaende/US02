# %%
import networkx as nx

# %%
G = nx.DiGraph()

# the nodes
G.add_node('x0')
G.add_node('x1')
G.add_node('x2')
G.add_node('x3')
G.add_node('x4')
G.add_node('x5')
G.add_node('x6')
G.add_node('x7')
G.add_node('x8')

# add edges from x0
G.add_edge('x0','x1',weight='20')
G.add_edge('x0','x2',weight='1')
G.add_edge('x0','x3',weight='10')

G.add_weighted_edges_from(edges)

nx.draw_networkx(G)

# %%
path = nx.single_source_dijkstra_path(G,0)
path
# Out:
# {0: [0], 2: [0, 2], 3: [0, 2, 3], 1: [0, 1], 4: [0, 2, 4]}
